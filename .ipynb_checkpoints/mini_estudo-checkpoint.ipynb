# %%
# ============================================================
# ICC305 - Avaliação de Desempenho
# Mini Estudo 1 - Estatística Descritiva
# ============================================================

# ============================================================
# 1. IMPORTS
# ============================================================

import pandas as pd
import numpy as np

from scipy import stats

import matplotlib.pyplot as plt

# %%
# ============================================================
# 2. CARREGAMENTO DOS DADOS
# ============================================================

arquivo_arthur = "./resultados_sys_art/baseline_postgres.csv"
arquivo_giovana = "./resultados_sys_gio/baseline_postgres.csv"

df_arthur = pd.read_csv(arquivo_arthur, sep=";")
df_giovana = pd.read_csv(arquivo_giovana, sep=";")

# %%
# ============================================================
# 3. UNIFICAÇÃO DOS DATASETS
# ============================================================

df = pd.concat([df_arthur, df_giovana], ignore_index=True)

print("Quantidade total de amostras:")
print(len(df))

print("\nSistemas encontrados:")
print(df["sistema"].unique())
# Out:
# Quantidade total de amostras:
# 2400
#
# Sistemas encontrados:
# <StringArray>
# ['sistema_arthur', 'sistema_giovana']
# Length: 2, dtype: str

# %%
# ============================================================
# 4. LIMPEZA E TIPAGEM
# ============================================================

df["valor"] = pd.to_numeric(df["valor"], errors="coerce")
df["tempo"] = pd.to_numeric(df["tempo"], errors="coerce")
df["num_tuplas"] = pd.to_numeric(df["num_tuplas"], errors="coerce")

df["timestamp"] = pd.to_datetime(df["timestamp"])

print("\nDados após limpeza:")
print(df.info())
# Out:
# Dados após limpeza:
# <class 'pandas.DataFrame'>
# RangeIndex: 2400 entries, 0 to 2399
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   run         2400 non-null   int64
#  1   timestamp   2400 non-null   datetime64[us]
#  2   sistema     2400 non-null   str
#  3   query_id    2400 non-null   int64
#  4   carga       2400 non-null   str
#  5   categoria   2400 non-null   str
#  6   metrica     2400 non-null   str
#  7   unidade     2400 non-null   str
#  8   valor       2400 non-null   float64
#  9   tempo       2400 non-null   float64
#  10  num_tuplas  2400 non-null   int64
#  11  observacao  2400 non-null   str
# dtypes: datetime64[us](1), float64(2), int64(3), str(6)
# memory usage: 225.1 KB
# None

# %%
# ============================================================
# 5. FUNÇÃO AUXILIAR PARA IC95%
# ============================================================
import numpy as np
import scipy.stats as st

def intervalo_confianca_95(valores):
    n = len(valores)
    media = np.mean(valores)
    
    if n < 2:
        return media, media
        
    desvio = np.std(valores, ddof=1)
    
    if desvio == 0.0 or np.isnan(desvio):
        return media, media
        
    erro_padrao = desvio / np.sqrt(n)
    
    ic_inf, ic_sup = st.t.interval(0.95, df=n-1, loc=media, scale=erro_padrao)
    
    return ic_inf, ic_sup

# %%
# ============================================================
# 6. ESTATÍSTICA DESCRITIVA POR SISTEMA
# ============================================================

estatisticas_sistema = []

for sistema, grupo in df.groupby("sistema"):

    valores = grupo["valor"]

    ic_inf, ic_sup = intervalo_confianca_95(valores)

    estatisticas_sistema.append({
        "sistema": sistema,
        "n_amostras": len(valores),
        "media_tp_ms": valores.mean(),
        "mediana_tp_ms": valores.median(),
        "min_tp_ms": valores.min(),
        "max_tp_ms": valores.max(),
        "desvio_padrao": valores.std(),
        "ic95_inf": ic_inf,
        "ic95_sup": ic_sup
    })

df_estatisticas_sistema = pd.DataFrame(estatisticas_sistema)

print("\n===================================================")
print("ESTATÍSTICA DESCRITIVA POR SISTEMA")
print("===================================================\n")

print(df_estatisticas_sistema)
# Out:
# ===================================================
# ESTATÍSTICA DESCRITIVA POR SISTEMA
# ===================================================
#
#            sistema  n_amostras  media_tp_ms  mediana_tp_ms  min_tp_ms  \
# 0   sistema_arthur        1200   207.082238       0.944695   0.000000
# 1  sistema_giovana        1200   212.922249       0.499748   0.005325
#
#      max_tp_ms  desvio_padrao    ic95_inf    ic95_sup
# 0  1906.742524     455.070474  181.308658  232.855818
# 1  1687.223981     429.618422  188.590183  237.254315

# %%
# ============================================================
# 7. ESTATÍSTICA DESCRITIVA POR CATEGORIA
# ============================================================

estatisticas_categoria = []

for (sistema, categoria), grupo in df.groupby(["sistema", "categoria"]):
    valores = grupo["valor"]
    ic_inf, ic_sup = intervalo_confianca_95(valores)

    estatisticas_categoria.append({
        "sistema": sistema,
        "categoria": categoria,
        "n_amostras": len(valores),
        "media_tp_ms": valores.mean(),
        "mediana_tp_ms": valores.median(),
        "min_tp_ms": valores.min(),
        "max_tp_ms": valores.max(),
        "desvio_padrao": valores.std(),
        "ic95_inf": ic_inf,
        "ic95_sup": ic_sup
    })

df_estatisticas_categoria = pd.DataFrame(estatisticas_categoria)

df_estatisticas_categoria = df_estatisticas_categoria.sort_values(
    by=["categoria", "sistema"]
).reset_index(drop=True)

print("\n===================================================")
print("ESTATÍSTICA DESCRITIVA POR CATEGORIA")
print("===================================================\n")

print(df_estatisticas_categoria)
# Out:
# ===================================================
# ESTATÍSTICA DESCRITIVA POR CATEGORIA
# ===================================================
#
#             sistema       categoria  n_amostras  media_tp_ms  mediana_tp_ms  \
# 0    sistema_arthur      Agregações         180     0.017042       0.007371
# 1   sistema_giovana      Agregações         180     0.016315       0.006940
# 2    sistema_arthur         Filtros         240   585.724567     300.295012
# 3   sistema_giovana         Filtros         240   590.699002     480.603892
# 4    sistema_arthur        Group By         150    17.433368       0.020667
# 5   sistema_giovana        Group By         150    16.719020       0.021749
# 6    sistema_arthur           Joins         270   371.459210       4.902594
# 7   sistema_giovana           Joins         270   391.250842       7.203717
# 8    sistema_arthur  Lookup Simples         240     4.585781       1.656456
# 9   sistema_giovana  Lookup Simples         240     4.460396       1.571727
# 10   sistema_arthur        Order By          60     0.276841       0.269773
# 11  sistema_giovana        Order By          60     0.088283       0.086080
# 12   sistema_arthur        Subquery          60    64.925533      62.998756
# 13  sistema_giovana        Subquery          60    75.243821      70.023136
#
#     min_tp_ms    max_tp_ms  desvio_padrao    ic95_inf    ic95_sup
# 0    0.005280     0.038799       0.014474    0.014913    0.019171
# 1    0.005325     0.037856       0.014004    0.014255    0.018375
# 2    0.000000  1906.742524     657.533257  502.113268  669.335866
# 3    0.498566  1687.223981     537.328073  522.372879  659.025125
# 4    0.015309    89.673568      34.830713   11.813753   23.052983
# 5    0.014743    87.983795      33.439198   11.323913   22.114127
# 6    0.041798  1397.432144     532.357369  307.672848  435.245572
# 7    0.042491  1301.874414     548.484258  325.532177  456.969508
# 8    0.005943    22.511875       6.303021    3.784295    5.387267
# 9    0.005405    22.923687       6.098277    3.684945    5.235847
# 10   0.075068     0.491104       0.202319    0.224576    0.329105
# 11   0.071966     0.106694       0.013514    0.084792    0.091774
# 12  21.990656   109.480091      42.303863   53.997287   75.853780
# 13  23.701603   127.093112      48.888172   62.614667   87.872975

# %%
# ============================================================
# 8. ESTATÍSTICA DESCRITIVA POR QUERY
# ============================================================

estatisticas_query = []

for (sistema, query_id), grupo in df.groupby(["sistema", "query_id"]):

    valores = grupo["valor"]

    ic_inf, ic_sup = intervalo_confianca_95(valores)

    estatisticas_query.append({
        "sistema": sistema,
        "query_id": query_id,
        "titulo": grupo["carga"].iloc[0],
        "categoria": grupo["categoria"].iloc[0],
        "n_amostras": len(valores),
        "media_tp_ms": valores.mean(),
        "mediana_tp_ms": valores.median(),
        "min_tp_ms": valores.min(),
        "max_tp_ms": valores.max(),
        "desvio_padrao": valores.std(),
        "ic95_inf": ic_inf,
        "ic95_sup": ic_sup
    })

df_estatisticas_query = pd.DataFrame(estatisticas_query)

df_estatisticas_query = df_estatisticas_query.sort_values(
    by=["query_id", "sistema"]
).reset_index(drop=True)


print("\n===================================================")
print("ESTATÍSTICA DESCRITIVA POR QUERY")
print("===================================================\n")

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)

print(df_estatisticas_query)
# Out:
# ===================================================
# ESTATÍSTICA DESCRITIVA POR QUERY
# ===================================================
#
#             sistema  query_id                                        titulo       categoria  n_amostras  media_tp_ms  mediana_tp_ms    min_tp_ms    max_tp_ms  desvio_padrao     ic95_inf     ic95_sup
# 0    sistema_arthur         1              Busca básica de produto por ASIN  Lookup Simples          30     0.095989       0.032390     0.030460     1.174397       0.214302     0.015967     0.176011
# 1   sistema_giovana         1              Busca básica de produto por ASIN  Lookup Simples          30     0.153282       0.057655     0.016204     1.607092       0.301136     0.040836     0.265728
# 2    sistema_arthur         2     Busca do identificador interno do produto  Lookup Simples          30     3.802173       3.808960     2.175436     5.287145       0.807292     3.500725     4.103621
# 3   sistema_giovana         2     Busca do identificador interno do produto  Lookup Simples          30     4.243896       4.250464     1.539565     6.060790       1.162522     3.809804     4.677989
# 4    sistema_arthur         3                Busca de reviews de um produto  Lookup Simples          30     0.074442       0.074763     0.072142     0.076285       0.000929     0.074095     0.074789
# 5   sistema_giovana         3                Busca de reviews de um produto  Lookup Simples          30     0.066216       0.066438     0.062544     0.068284       0.001111     0.065801     0.066630
# 6    sistema_arthur         4                   Busca de produtos similares  Lookup Simples          30    18.156093      17.774048    12.236218    22.511875       2.335901    17.283853    19.028333
# 7   sistema_giovana         4                   Busca de produtos similares  Lookup Simples          30    16.717182      17.905869     8.079946    22.923687       3.509033    15.406887    18.027476
# 8    sistema_arthur         5             Busca de categorias de um produto  Lookup Simples          30    10.697552      10.857086     6.398894    14.824478       2.388329     9.805735    11.589368
# 9   sistema_giovana         5             Busca de categorias de um produto  Lookup Simples          30    11.070088      11.632745     3.674120    16.245106       3.225348     9.865723    12.274453
# 10   sistema_arthur         6      Busca de reviews positivos de um produto  Lookup Simples          30     0.060434       0.060537     0.058239     0.061449       0.000777     0.060144     0.060724
# 11  sistema_giovana         6      Busca de reviews positivos de um produto  Lookup Simples          30     0.051583       0.051971     0.048517     0.053066       0.001077     0.051180     0.051985
# 12   sistema_arthur         7          Busca de reviews úteis de um produto  Lookup Simples          30     0.006229       0.006246     0.005943     0.006326       0.000079     0.006200     0.006259
# 13  sistema_giovana         7          Busca de reviews úteis de um produto  Lookup Simples          30     0.006079       0.006118     0.005405     0.006214       0.000147     0.006024     0.006134
# 14   sistema_arthur         8     Busca de informações resumidas do produto  Lookup Simples          30     3.793336       3.919442     2.138516     4.728043       0.581453     3.576219     4.010454
# 15  sistema_giovana         8     Busca de informações resumidas do produto  Lookup Simples          30     3.374844       3.529805     1.603888     4.593625       0.812660     3.071392     3.678297
# 16   sistema_arthur         9                  Produtos com sales rank alto         Filtros          30   373.113453     374.436853   358.561654   384.343600       6.257064   370.777026   375.449879
# 17  sistema_giovana         9                  Produtos com sales rank alto         Filtros          30   194.477539     195.688033   169.911176   202.436434       6.676361   191.984545   196.970533
# 18   sistema_arthur        10                 Produtos com muitos downloads         Filtros          30    17.110729      17.188415    16.077823    17.646872       0.360040    16.976288    17.245170
# 19  sistema_giovana        10                 Produtos com muitos downloads         Filtros          30    14.939458      14.982126    14.233578    15.361270       0.262900    14.841290    15.037627
# 20   sistema_arthur        11                    Reviews com alta utilidade         Filtros          30   235.160255     237.148036   199.456093   242.028370       7.853213   232.227817   238.092693
# 21  sistema_giovana        11                    Reviews com alta utilidade         Filtros          30   236.193286     237.419132   216.093817   243.375078       5.776866   234.036168   238.350403
# 22   sistema_arthur        12            Reviews negativos com muitos votos         Filtros          30   832.133913     839.845009   779.530201   859.867262      19.709060   824.774428   839.493397
# 23  sistema_giovana        12            Reviews negativos com muitos votos         Filtros          30   844.651918     847.374991   812.198250   865.408669      12.643566   839.930733   849.373103
# 24   sistema_arthur        13                        Produtos do grupo Book         Filtros          30  1822.368458    1824.969362  1688.526731  1906.742524      61.859179  1799.269861  1845.467056
# 25  sistema_giovana        13                        Produtos do grupo Book         Filtros          30   876.694013     879.156395   717.832706   925.107212      38.742530   862.227314   891.160712
# 26   sistema_arthur        14                               Categorias raiz         Filtros          30     1.054116       1.066170     0.911671     1.171749       0.052069     1.034673     1.073559
# 27  sistema_giovana        14                               Categorias raiz         Filtros          30     0.588484       0.591423     0.498566     0.699505       0.050600     0.569589     0.607378
# 28   sistema_arthur        15                              Reviews recentes         Filtros          30  1404.855610    1428.884877  1283.346049  1482.768257      54.785899  1384.398219  1425.313000
# 29  sistema_giovana        15                              Reviews recentes         Filtros          30  1624.589004    1636.982848  1543.493989  1687.223981      40.061303  1609.629868  1639.548141
# 30   sistema_arthur        16                        Produtos sem downloads         Filtros          30     0.000000       0.000000     0.000000     0.000000       0.000000     0.000000     0.000000
# 31  sistema_giovana        16                        Produtos sem downloads         Filtros          30   933.458317     929.083737   804.509216   997.279961      43.418989   917.245400   949.671234
# 32   sistema_arthur        17               Produto e identificador interno           Joins          30     2.523415       2.604099     1.497324     3.118869       0.353629     2.391368     2.655462
# 33  sistema_giovana        17               Produto e identificador interno           Joins          30     0.152313       0.141098     0.111028     0.197827       0.028861     0.141536     0.163090
# 34   sistema_arthur        18                  Produto e reviews associados           Joins          30     0.077196       0.077292     0.074006     0.078559       0.001058     0.076801     0.077591
# 35  sistema_giovana        18                  Produto e reviews associados           Joins          30     0.096961       0.097462     0.091727     0.100455       0.002217     0.096133     0.097789
# 36   sistema_arthur        19               Produto e categorias associadas           Joins          30     4.752962       4.902594     2.688714     7.662424       1.271950     4.278007     5.227916
# 37  sistema_giovana        19               Produto e categorias associadas           Joins          30     6.410034       7.321963     2.261528     8.653551       1.992239     5.666120     7.153949
# 38   sistema_arthur        20                 Produtos similares detalhados           Joins          30    21.822820      23.295164    10.474407    31.130149       6.111374    19.540795    24.104844
# 39  sistema_giovana        20                 Produtos similares detalhados           Joins          30    25.713573      27.791265     5.939519    34.793501       7.550689    22.894099    28.533047
# 40   sistema_arthur        21                    Reviews e dados do produto           Joins          30  1365.655827    1368.512575  1318.843707  1397.432144      17.613786  1359.078731  1372.232923
# 41  sistema_giovana        21                    Reviews e dados do produto           Joins          30  1118.001484    1120.390036  1063.855115  1141.190941      16.171579  1111.962917  1124.040051
# 42   sistema_arthur        22              Produto com categorias e reviews           Joins          30     0.042638       0.042570     0.041798     0.043359       0.000440     0.042474     0.042802
# 43  sistema_giovana        22              Produto com categorias e reviews           Joins          30     0.043835       0.043844     0.042491     0.044823       0.000541     0.043634     0.044037
# 44   sistema_arthur        23              Categorias e produtos associados           Joins          30  1071.159084    1075.025912  1020.571373  1114.922741      20.666433  1063.442111  1078.876057
# 45  sistema_giovana        23              Categorias e produtos associados           Joins          30  1267.249377    1269.572067  1222.612460  1301.874414      21.407606  1259.255646  1275.243109
# 46   sistema_arthur        24                  Produtos similares e reviews           Joins          30     0.220382       0.220711     0.214441     0.223140       0.002115     0.219593     0.221172
# 47  sistema_giovana        24                  Produtos similares e reviews           Joins          30     0.172703       0.172671     0.168763     0.176130       0.001679     0.172077     0.173330
# 48   sistema_arthur        25            Produto e quantidade de categorias           Joins          30   876.878565     880.369398   807.111983   911.102377      21.827377   868.728088   885.029041
# 49  sistema_giovana        25            Produto e quantidade de categorias           Joins          30  1103.417301    1103.411745  1040.730509  1138.493361      18.942222  1096.344158  1110.490443
# 50   sistema_arthur        26                  Quantidade total de produtos      Agregações          30     0.008669       0.008745     0.008085     0.008994       0.000226     0.008585     0.008754
# 51  sistema_giovana        26                  Quantidade total de produtos      Agregações          30     0.008815       0.008817     0.007808     0.009203       0.000289     0.008707     0.008923
# 52   sistema_arthur        27             Média de avaliações de um produto      Agregações          30     0.006381       0.006458     0.005280     0.006524       0.000242     0.006290     0.006471
# 53  sistema_giovana        27             Média de avaliações de um produto      Agregações          30     0.005527       0.005534     0.005325     0.005629       0.000066     0.005503     0.005552
# 54   sistema_arthur        28                              Maior sales rank      Agregações          30     0.037302       0.037344     0.034914     0.038469       0.000850     0.036985     0.037620
# 55  sistema_giovana        28                              Maior sales rank      Agregações          30     0.035886       0.035995     0.034198     0.037006       0.000715     0.035619     0.036153
# 56   sistema_arthur        29                              Menor sales rank      Agregações          30     0.037487       0.037754     0.030620     0.038799       0.001428     0.036954     0.038021
# 57  sistema_giovana        29                              Menor sales rank      Agregações          30     0.036099       0.036145     0.034731     0.037856       0.000720     0.035830     0.036368
# 58   sistema_arthur        30                     Soma total de votos úteis      Agregações          30     0.005886       0.005905     0.005735     0.005989       0.000069     0.005860     0.005912
# 59  sistema_giovana        30                     Soma total de votos úteis      Agregações          30     0.005963       0.005961     0.005808     0.006071       0.000056     0.005942     0.005984
# 60   sistema_arthur        31              Quantidade de reviews do produto      Agregações          30     0.006528       0.006548     0.005955     0.006657       0.000123     0.006482     0.006574
# 61  sistema_giovana        31              Quantidade de reviews do produto      Agregações          30     0.005599       0.005601     0.005416     0.005726       0.000064     0.005575     0.005623
# 62   sistema_arthur        32                 Quantidade de reviews por ano        Group By          30     0.020632       0.020667     0.019931     0.020922       0.000211     0.020553     0.020711
# 63  sistema_giovana        32                 Quantidade de reviews por ano        Group By          30     0.021696       0.021749     0.020939     0.022017       0.000260     0.021599     0.021793
# 64   sistema_arthur        33                Quantidade de reviews por nota        Group By          30     0.017446       0.017465     0.016922     0.017732       0.000196     0.017372     0.017519
# 65  sistema_giovana        33                Quantidade de reviews por nota        Group By          30     0.017179       0.017172     0.016710     0.017583       0.000191     0.017108     0.017250
# 66   sistema_arthur        34              Quantidade de produtos por grupo        Group By          30     0.276719       0.276624     0.270003     0.285377       0.003860     0.275278     0.278161
# 67  sistema_giovana        34              Quantidade de produtos por grupo        Group By          30     0.218020       0.218776     0.210610     0.224313       0.003637     0.216662     0.219378
# 68   sistema_arthur        35                 Média de votos úteis por nota        Group By          30     0.015697       0.015710     0.015309     0.016011       0.000177     0.015631     0.015763
# 69  sistema_giovana        35                 Média de votos úteis por nota        Group By          30     0.015501       0.015519     0.014743     0.015857       0.000217     0.015420     0.015581
# 70   sistema_arthur        36          Quantidade de produtos por categoria        Group By          30    86.836345      86.895118    80.595895    89.673568       2.142344    86.036381    87.636310
# 71  sistema_giovana        36          Quantidade de produtos por categoria        Group By          30    83.322705      83.548537    76.125902    87.983795       2.971170    82.213252    84.432158
# 72   sistema_arthur        37                 Top 20 produtos mais baixados        Order By          30     0.477391       0.477776     0.462272     0.491104       0.007852     0.474460     0.480323
# 73  sistema_giovana        37                 Top 20 produtos mais baixados        Order By          30     0.101584       0.102050     0.096147     0.106694       0.002227     0.100753     0.102416
# 74   sistema_arthur        38                     Top 30 reviews mais úteis        Order By          30     0.076290       0.076264     0.075068     0.077274       0.000506     0.076101     0.076479
# 75  sistema_giovana        38                     Top 30 reviews mais úteis        Order By          30     0.074982       0.075170     0.071966     0.076014       0.000745     0.074704     0.075260
# 76   sistema_arthur        39  Produtos acima da média global de avaliações        Subquery          30   106.862195     106.944121   102.492347   109.480091       1.477524   106.310478   107.413911
# 77  sistema_giovana        39  Produtos acima da média global de avaliações        Subquery          30   123.672269     124.612522   112.005199   127.093112       2.951622   122.570115   124.774423
# 78   sistema_arthur        40         Produtos com mais reviews que a média        Subquery          30    22.988872      23.015286    21.990656    23.505165       0.325225    22.867431    23.110313
# 79  sistema_giovana        40         Produtos com mais reviews que a média        Subquery          30    26.815372      27.190449    23.701603    28.041074       1.198020    26.368024    27.262720

# %%
# ============================================================
# 9. BOXPLOT POR SISTEMA
# ============================================================

plt.figure(figsize=(8, 6))

df.boxplot(
    column="valor",
    by="sistema"
)

plt.title("Distribuição de Tuplas por Milissegundo por Sistema")
plt.suptitle("")

plt.xlabel("Sistema")
plt.ylabel("Tuplas por milissegundo (tp/ms)")

plt.tight_layout()

plt.show()

# %%
# ============================================================
# 10. HISTOGRAMA GERAL
# ============================================================

plt.figure(figsize=(10, 6))

for sistema in df["sistema"].unique():

    subset = df[df["sistema"] == sistema]

    plt.hist(
        subset["valor"],
        bins=30,
        alpha=0.5,
        label=sistema
    )

plt.xlabel("Tuplas por milissegundo (tp/ms)")
plt.ylabel("Frequência")

plt.title("Histograma de Throughput por Sistema")

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# 11. BOXPLOT POR CATEGORIA
# ============================================================

categorias = sorted(df["categoria"].unique())

for categoria in categorias:

    subset = df[df["categoria"] == categoria]

    plt.figure(figsize=(8, 6))

    subset.boxplot(
        column="valor",
        by="sistema"
    )

    plt.title(f"Categoria: {categoria}")
    plt.suptitle("")

    plt.ylabel("Tuplas por milissegundo (tp/ms)")

    plt.tight_layout()

    plt.show()

# %%
# ============================================================
# 12. RESUMO FINAL
# ============================================================

print("\n===================================================")
print("RESUMO FINAL")
print("===================================================\n")

for sistema in df["sistema"].unique():

    subset = df[df["sistema"] == sistema]

    print(f"Sistema: {sistema}")
    print(f"Média tp/ms: {subset['valor'].mean():.4f}")
    print(f"Mediana tp/ms: {subset['valor'].median():.4f}")
    print(f"Desvio padrão: {subset['valor'].std():.4f}")
    print("-" * 50)
# Out:
# ===================================================
# RESUMO FINAL
# ===================================================
#
# Sistema: sistema_arthur
# Média tp/ms: 207.0822
# Mediana tp/ms: 0.9447
# Desvio padrão: 455.0705
# --------------------------------------------------
# Sistema: sistema_giovana
# Média tp/ms: 212.9222
# Mediana tp/ms: 0.4997
# Desvio padrão: 429.6184
# --------------------------------------------------
